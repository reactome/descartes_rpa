# %%
from descartes_rpa.convert.loom import loom_to_anndata
from descartes_rpa.analyze.analyze import scanpy_format
from descartes_rpa.analyze.analyze import get_pathways_for_group
from descartes_rpa.fetch.descartes import fetch_descartes_by_tissue

# %%
fetch_descartes_by_tissue(["Intestine"], out_dir="../data/input")
# Out:
# Downloading Intestine tissue Human Single-Cell data from Descartes database
# data url: https://shendure-web.gs.washington.edu/content/members/cao1025/public/FCA_RNA_supp_files/scanpy_cells_by_tissue/Intestine_processed.loom
# Downloaded ../data/input/Intestine_data.loom to ../data/input

# %%
adata = loom_to_anndata("../data/input/Intestine_data.loom")
scanpy_format(adata=adata)
get_pathways_for_group(adata)
# Out:
# /home/joao/miniconda3/envs/descartes-rpa/lib/python3.9/site-packages/anndata/_core/anndata.py:120: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/joao/miniconda3/envs/descartes-rpa/lib/python3.9/site-packages/anndata/utils.py:111: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-5', 'SNORD116-6']
#   warnings.warn(
# ... storing 'Assay' as categorical
# ... storing 'Batch' as categorical
# ... storing 'Experiment_batch' as categorical
# ... storing 'Fetus_id' as categorical
# ... storing 'Main_cluster_name' as categorical
# ... storing 'Organ' as categorical
# ... storing 'Organ_cell_lineage' as categorical
# ... storing 'RT_group' as categorical
# ... storing 'Sex' as categorical
# ... storing 'exon_intron' as categorical
# ... storing 'gene_type' as categorical

# %%
from descartes_rpa.io.save import save_data_with_pathways
import os

# %%
dir_path = "../data/output/Intestine"
os.mkdir(dir_path)
file = "Intestine"

# %%
save_data_with_pathways(adata, directory=dir_path, file=file)
# Out:
# Saving AnnData structure to ../data/output/Intestine/Intestine.h5ad
# Saving pathway data from Vascular endothelial cells clusters to ../data/output/Intestine
# Saving pathway data from Stromal cells clusters to ../data/output/Intestine
# Saving pathway data from Intestinal epithelial cells clusters to ../data/output/Intestine
# Saving pathway data from ENS glia clusters to ../data/output/Intestine
# Saving pathway data from Lymphoid cells clusters to ../data/output/Intestine
# Saving pathway data from Myeloid cells clusters to ../data/output/Intestine
# Saving pathway data from Smooth muscle cells clusters to ../data/output/Intestine
# Saving pathway data from Mesothelial cells clusters to ../data/output/Intestine
# Saving pathway data from ENS neurons clusters to ../data/output/Intestine
# Saving pathway data from Chromaffin cells clusters to ../data/output/Intestine
# Saving pathway data from Lymphatic endothelial cells clusters to ../data/output/Intestine
# Saving pathway data from Erythroblasts clusters to ../data/output/Intestine

# %%
from descartes_rpa.io.load import load_data_with_pathways

# %%
loaded_adata = load_data_with_pathways(directory=dir_path)
# Out:
# Loading ../data/output/Intestine/Lymphatic_endothelial_cells_pathways.csv pathway data.
# Loading ../data/output/Intestine/Smooth_muscle_cells_pathways.csv pathway data.
# Loading ../data/output/Intestine/Chromaffin_cells_pathways.csv pathway data.
# Loading ../data/output/Intestine/Myeloid_cells_pathways.csv pathway data.
# Loading ../data/output/Intestine/Lymphoid_cells_pathways.csv pathway data.
# Loading ../data/output/Intestine/ENS_glia_pathways.csv pathway data.
# Loading ../data/output/Intestine/Vascular_endothelial_cells_pathways.csv pathway data.
# Loading ../data/output/Intestine/Mesothelial_cells_pathways.csv pathway data.
# Loading ../data/output/Intestine/Erythroblasts_pathways.csv pathway data.
# Loading ../data/output/Intestine/ENS_neurons_pathways.csv pathway data.
# Loading ../data/output/Intestine/Stromal_cells_pathways.csv pathway data.
# Loading ../data/output/Intestine/Intestinal_epithelial_cells_pathways.csv pathway data.
# Loading ../data/output/Intestine/Intestine.h5ad AnnData file.

# %%
loaded_adata.uns["pathways"].keys()
# Out:
# odict_keys(['Lymphatic_endothelial_cells', 'Smooth_muscle_cells', 'Chromaffin_cells', 'Myeloid_cells', 'Lymphoid_cells', 'ENS_glia', 'Vascular_endothelial_cells', 'Mesothelial_cells', 'Erythroblasts', 'ENS_neurons', 'Stromal_cells', 'Intestinal_epithelial_cells'])

# %%
loaded_adata.uns["pathways"]["Intestinal_epithelial_cells"]
# Out:
#               stId     dbId  \
# 0     R-HSA-210745   210745
# 1     R-HSA-186712   186712
# 2    R-HSA-1266738  1266738
# 3    R-HSA-8941333  8941333
# 4     R-HSA-975956   975956
# ..             ...      ...
# 139   R-HSA-388396   388396
# 140   R-HSA-556833   556833
# 141   R-HSA-372790   372790
# 142   R-HSA-168256   168256
# 143   R-HSA-162582   162582
#
#                                                   name  \
# 0          Regulation of gene expression in beta cells
# 1                  Regulation of beta-cell development
# 2                                Developmental Biology
# 3    RUNX2 regulates genes involved in differentiat...
# 4    Nonsense Mediated Decay (NMD) independent of t...
# ..                                                 ...
# 139                         GPCR downstream signalling
# 140                               Metabolism of lipids
# 141                                  Signaling by GPCR
# 142                                      Immune System
# 143                                Signal Transduction
#
#                                                species    llp  \
# 0    {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...   True
# 1    {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...  False
# 2    {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...  False
# 3    {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...   True
# 4    {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...   True
# ..                                                 ...    ...
# 139  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...  False
# 140  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...  False
# 141  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...  False
# 142  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...  False
# 143  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...  False
#
#                                               entities  \
# 0    {'resource': 'TOTAL', 'total': 35, 'found': 6,...
# 1    {'resource': 'TOTAL', 'total': 67, 'found': 6,...
# 2    {'resource': 'TOTAL', 'total': 1262, 'found': ...
# 3    {'resource': 'TOTAL', 'total': 6, 'found': 2, ...
# 4    {'resource': 'TOTAL', 'total': 101, 'found': 4...
# ..                                                 ...
# 139  {'resource': 'TOTAL', 'total': 785, 'found': 1...
# 140  {'resource': 'TOTAL', 'total': 1437, 'found': ...
# 141  {'resource': 'TOTAL', 'total': 864, 'found': 1...
# 142  {'resource': 'TOTAL', 'total': 2681, 'found': ...
# 143  {'resource': 'TOTAL', 'total': 2993, 'found': ...
#
#                                              reactions  inDisease
# 0    {'resource': 'TOTAL', 'total': 12, 'found': 2,...      False
# 1    {'resource': 'TOTAL', 'total': 26, 'found': 2,...      False
# 2    {'resource': 'TOTAL', 'total': 556, 'found': 1...      False
# 3    {'resource': 'TOTAL', 'total': 2, 'found': 2, ...      False
# 4    {'resource': 'TOTAL', 'total': 1, 'found': 1, ...      False
# ..                                                 ...        ...
# 139  {'resource': 'TOTAL', 'total': 168, 'found': 1...      False
# 140  {'resource': 'TOTAL', 'total': 949, 'found': 1...      False
# 141  {'resource': 'TOTAL', 'total': 354, 'found': 1...      False
# 142  {'resource': 'TOTAL', 'total': 1623, 'found': ...      False
# 143  {'resource': 'TOTAL', 'total': 2445, 'found': ...      False
#
# [144 rows x 8 columns]

# %%
import scanpy as sc
sc.settings.set_figure_params(dpi=300, facecolor='white')

# %%
sc.pl.umap(loaded_adata, color="Main_cluster_name")
