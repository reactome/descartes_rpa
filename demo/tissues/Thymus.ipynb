# %%
from descartes_rpa.convert.loom import loom_to_anndata
from descartes_rpa.analyze.analyze import scanpy_format
from descartes_rpa import get_pathways_for_group
from descartes_rpa.fetch.descartes import fetch_descartes_by_tissue

# %%
fetch_descartes_by_tissue(["Thymus"], out_dir="../data/input")

# %%
adata = loom_to_anndata("../../data/input/Thymus_data.loom")
scanpy_format(adata=adata)
get_pathways_for_group(adata)
# Out:
# /home/joao/miniconda3/envs/descartes-rpa/lib/python3.9/site-packages/anndata/_core/anndata.py:120: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/joao/miniconda3/envs/descartes-rpa/lib/python3.9/site-packages/anndata/utils.py:111: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-5', 'SNORD116-6']
#   warnings.warn(
# ... storing 'Assay' as categorical
# ... storing 'Experiment_batch' as categorical
# ... storing 'Fetus_id' as categorical
# ... storing 'Main_cluster_name' as categorical
# ... storing 'Organ' as categorical
# ... storing 'Organ_cell_lineage' as categorical
# ... storing 'RT_group' as categorical
# ... storing 'Sex' as categorical
# ... storing 'exon_intron' as categorical
# ... storing 'gene_type' as categorical

# %%
from descartes_rpa.io.save import save_data_with_pathways
import os

# %%
dir_path = "../../data/output/Thymus"
file = "Thymus"

# %%
save_data_with_pathways(adata, directory=dir_path, file=file)
# Out:
# Saving AnnData structure to ../../data/output/Thymus/Thymus.h5ad
# Saving pathway data from Thymocytes clusters to ../../data/output/Thymus
# Saving pathway data from Antigen presenting cells clusters to ../../data/output/Thymus
# Saving pathway data from Thymic epithelial cells clusters to ../../data/output/Thymus
# Saving pathway data from Stromal cells clusters to ../../data/output/Thymus
# Saving pathway data from Vascular endothelial cells clusters to ../../data/output/Thymus

# %%
from descartes_rpa.io.load import load_data_with_pathways

# %%
loaded_adata = load_data_with_pathways(directory=dir_path)
# Out:
# Loading ../../data/output/Thymus/Thymocytes_pathways.csv pathway data.
# Loading ../../data/output/Thymus/Vascular_endothelial_cells_pathways.csv pathway data.
# Loading ../../data/output/Thymus/Antigen_presenting_cells_pathways.csv pathway data.
# Loading ../../data/output/Thymus/Stromal_cells_pathways.csv pathway data.
# Loading ../../data/output/Thymus/Thymic_epithelial_cells_pathways.csv pathway data.
# Loading ../../data/output/Thymus/Thymus.h5ad AnnData file.

# %%
loaded_adata.uns["pathways"].keys()
# Out:
# odict_keys(['Thymocytes', 'Vascular_endothelial_cells', 'Antigen_presenting_cells', 'Stromal_cells', 'Thymic_epithelial_cells'])

# %%
loaded_adata.uns["pathways"]["Thymic_epithelial_cells"]
# Out:
#              stId     dbId                                               name  \
# 0    R-HSA-428542   428542  Regulation of commissural axon pathfinding by ...
# 1   R-HSA-8985801  8985801          Regulation of cortical dendrite branching
# 2    R-HSA-376176   376176                        Signaling by ROBO receptors
# 3   R-HSA-9010553  9010553        Regulation of expression of SLITs and ROBOs
# 4    R-HSA-422475   422475                                      Axon guidance
# 5   R-HSA-9675108  9675108                         Nervous system development
# 6    R-HSA-373756   373756                                   SDK interactions
# 7    R-HSA-373752   373752                                 Netrin-1 signaling
# 8   R-HSA-8985586  8985586                SLIT2:ROBO1 increases RHOA activity
# 9    R-HSA-428890   428890                 Role of ABL in ROBO-SLIT signaling
# 10   R-HSA-428543   428543                     Inactivation of CDC42 and RAC1
# 11  R-HSA-9010642  9010642                          ROBO receptors bind AKAP5
# 12   R-HSA-428540   428540                                 Activation of RAC1
# 13  R-HSA-1971475  1971475  A tetrasaccharide linker sequence is required ...
# 14   R-HSA-418457   418457                                       cGMP effects
# 15    R-HSA-73980    73980       RNA Polymerase III Transcription Termination
# 16   R-HSA-947581   947581                   Molybdenum cofactor biosynthesis
# 17   R-HSA-392517   392517                                    Rap1 signalling
# 18  R-HSA-1266738  1266738                              Developmental Biology
# 19  R-HSA-8874081  8874081                       MET activates PTK2 signaling
# 20  R-HSA-2022928  2022928                                HS-GAG biosynthesis
# 21   R-HSA-392154   392154          Nitric oxide stimulates guanylate cyclase
# 22  R-HSA-2024096  2024096                                 HS-GAG degradation
# 23  R-HSA-8875878  8875878                         MET promotes cell motility
# 24   R-HSA-749476   749476  RNA Polymerase III Abortive And Retractive Ini...
# 25  R-HSA-2022090  2022090  Assembly of collagen fibrils and other multime...
# 26   R-HSA-421270   421270                    Cell-cell junction organization
# 27    R-HSA-74158    74158                   RNA Polymerase III Transcription
# 28  R-HSA-8948216  8948216                       Collagen chain trimerization
# 29   R-HSA-936837   936837                    Ion transport by P-type ATPases
# 30  R-HSA-1793185  1793185    Chondroitin sulfate/dermatan sulfate metabolism
# 31  R-HSA-1650814  1650814        Collagen biosynthesis and modifying enzymes
# 32   R-HSA-975634   975634                  Retinoid metabolism and transport
# 33  R-HSA-4086398  4086398                                       Ca2+ pathway
# 34  R-HSA-1638091  1638091        Heparan sulfate/heparin (HS-GAG) metabolism
# 35  R-HSA-6806834  6806834                                   Signaling by MET
# 36  R-HSA-6806667  6806667                 Metabolism of fat-soluble vitamins
# 37   R-HSA-446728   446728                         Cell junction organization
# 38   R-HSA-196854   196854               Metabolism of vitamins and cofactors
# 39  R-HSA-1474290  1474290                                 Collagen formation
# 40   R-HSA-418346   418346                               Platelet homeostasis
# 41   R-HSA-373760   373760                                 L1CAM interactions
# 42  R-HSA-1500931  1500931                            Cell-Cell communication
# 43  R-HSA-3858494  3858494             Beta-catenin independent WNT signaling
# 44  R-HSA-2187338  2187338                           Visual phototransduction
# 45  R-HSA-1630316  1630316                       Glycosaminoglycan metabolism
# 46   R-HSA-983712   983712                              Ion channel transport
# 47   R-HSA-196849   196849  Metabolism of water-soluble vitamins and cofac...
# 48  R-HSA-1474244  1474244                  Extracellular matrix organization
# 49   R-HSA-195721   195721                                   Signaling by WNT
# 50    R-HSA-71387    71387                        Metabolism of carbohydrates
# 51  R-HSA-9006934  9006934             Signaling by Receptor Tyrosine Kinases
# 52  R-HSA-9709957  9709957                                 Sensory Perception
# 53   R-HSA-109582   109582                                         Hemostasis
# 54   R-HSA-382551   382551                       Transport of small molecules
# 55  R-HSA-1280218  1280218                             Adaptive Immune System
# 56    R-HSA-74160    74160                    Gene expression (Transcription)
# 57   R-HSA-162582   162582                                Signal Transduction
# 58   R-HSA-168256   168256                                      Immune System
# 59  R-HSA-1430728  1430728                                         Metabolism
#
#                                               species    llp  \
# 0   {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...   True
# 1   {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...   True
# 2   {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...   True
# 3   {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...   True
# 4   {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...  False
# 5   {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...  False
# 6   {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...   True
# 7   {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...   True
# 8   {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...   True
# 9   {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...   True
# 10  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...   True
# 11  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...   True
# 12  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...   True
# 13  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...   True
# 14  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...   True
# 15  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...   True
# 16  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...   True
# 17  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...   True
# 18  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...  False
# 19  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...   True
# 20  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...   True
# 21  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...   True
# 22  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...   True
# 23  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...  False
# 24  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...   True
# 25  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...   True
# 26  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...  False
# 27  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...  False
# 28  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...   True
# 29  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...   True
# 30  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...  False
# 31  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...   True
# 32  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...   True
# 33  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...   True
# 34  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...  False
# 35  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...  False
# 36  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...  False
# 37  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...  False
# 38  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...  False
# 39  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...  False
# 40  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...   True
# 41  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...   True
# 42  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...  False
# 43  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...  False
# 44  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...  False
# 45  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...  False
# 46  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...   True
# 47  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...  False
# 48  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...   True
# 49  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...  False
# 50  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...  False
# 51  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...  False
# 52  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...  False
# 53  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...  False
# 54  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...  False
# 55  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...  False
# 56  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...  False
# 57  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...  False
# 58  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...  False
# 59  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...  False
#
#                                              entities  \
# 0   {'resource': 'TOTAL', 'total': 12, 'found': 3,...
# 1   {'resource': 'TOTAL', 'total': 4, 'found': 2, ...
# 2   {'resource': 'TOTAL', 'total': 235, 'found': 5...
# 3   {'resource': 'TOTAL', 'total': 183, 'found': 4...
# 4   {'resource': 'TOTAL', 'total': 584, 'found': 6...
# 5   {'resource': 'TOTAL', 'total': 620, 'found': 6...
# 6   {'resource': 'TOTAL', 'total': 2, 'found': 1, ...
# 7   {'resource': 'TOTAL', 'total': 59, 'found': 2,...
# 8   {'resource': 'TOTAL', 'total': 8, 'found': 1, ...
# 9   {'resource': 'TOTAL', 'total': 10, 'found': 1,...
# 10  {'resource': 'TOTAL', 'total': 12, 'found': 1,...
# 11  {'resource': 'TOTAL', 'total': 11, 'found': 1,...
# 12  {'resource': 'TOTAL', 'total': 15, 'found': 1,...
# 13  {'resource': 'TOTAL', 'total': 31, 'found': 1,...
# 14  {'resource': 'TOTAL', 'total': 18, 'found': 1,...
# 15  {'resource': 'TOTAL', 'total': 23, 'found': 1,...
# 16  {'resource': 'TOTAL', 'total': 27, 'found': 1,...
# 17  {'resource': 'TOTAL', 'total': 24, 'found': 1,...
# 18  {'resource': 'TOTAL', 'total': 1262, 'found': ...
# 19  {'resource': 'TOTAL', 'total': 32, 'found': 1,...
# 20  {'resource': 'TOTAL', 'total': 40, 'found': 1,...
# 21  {'resource': 'TOTAL', 'total': 35, 'found': 1,...
# 22  {'resource': 'TOTAL', 'total': 44, 'found': 1,...
# 23  {'resource': 'TOTAL', 'total': 45, 'found': 1,...
# 24  {'resource': 'TOTAL', 'total': 46, 'found': 1,...
# 25  {'resource': 'TOTAL', 'total': 67, 'found': 1,...
# 26  {'resource': 'TOTAL', 'total': 67, 'found': 1,...
# 27  {'resource': 'TOTAL', 'total': 46, 'found': 1,...
# 28  {'resource': 'TOTAL', 'total': 44, 'found': 1,...
# 29  {'resource': 'TOTAL', 'total': 71, 'found': 1,...
# 30  {'resource': 'TOTAL', 'total': 73, 'found': 1,...
# 31  {'resource': 'TOTAL', 'total': 76, 'found': 1,...
# 32  {'resource': 'TOTAL', 'total': 79, 'found': 1,...
# 33  {'resource': 'TOTAL', 'total': 81, 'found': 1,...
# 34  {'resource': 'TOTAL', 'total': 88, 'found': 1,...
# 35  {'resource': 'TOTAL', 'total': 88, 'found': 1,...
# 36  {'resource': 'TOTAL', 'total': 89, 'found': 1,...
# 37  {'resource': 'TOTAL', 'total': 94, 'found': 1,...
# 38  {'resource': 'TOTAL', 'total': 377, 'found': 2...
# 39  {'resource': 'TOTAL', 'total': 104, 'found': 1...
# 40  {'resource': 'TOTAL', 'total': 117, 'found': 1...
# 41  {'resource': 'TOTAL', 'total': 130, 'found': 1...
# 42  {'resource': 'TOTAL', 'total': 133, 'found': 1...
# 43  {'resource': 'TOTAL', 'total': 166, 'found': 1...
# 44  {'resource': 'TOTAL', 'total': 169, 'found': 1...
# 45  {'resource': 'TOTAL', 'total': 182, 'found': 1...
# 46  {'resource': 'TOTAL', 'total': 206, 'found': 1...
# 47  {'resource': 'TOTAL', 'total': 254, 'found': 1...
# 48  {'resource': 'TOTAL', 'total': 329, 'found': 1...
# 49  {'resource': 'TOTAL', 'total': 332, 'found': 1...
# 50  {'resource': 'TOTAL', 'total': 456, 'found': 1...
# 51  {'resource': 'TOTAL', 'total': 617, 'found': 1...
# 52  {'resource': 'TOTAL', 'total': 681, 'found': 1...
# 53  {'resource': 'TOTAL', 'total': 801, 'found': 1...
# 54  {'resource': 'TOTAL', 'total': 958, 'found': 1...
# 55  {'resource': 'TOTAL', 'total': 1004, 'found': ...
# 56  {'resource': 'TOTAL', 'total': 1855, 'found': ...
# 57  {'resource': 'TOTAL', 'total': 2993, 'found': ...
# 58  {'resource': 'TOTAL', 'total': 2681, 'found': ...
# 59  {'resource': 'TOTAL', 'total': 3633, 'found': ...
#
#                                             reactions  inDisease
# 0   {'resource': 'TOTAL', 'total': 5, 'found': 2, ...      False
# 1   {'resource': 'TOTAL', 'total': 2, 'found': 2, ...      False
# 2   {'resource': 'TOTAL', 'total': 60, 'found': 38...      False
# 3   {'resource': 'TOTAL', 'total': 20, 'found': 6,...      False
# 4   {'resource': 'TOTAL', 'total': 298, 'found': 3...      False
# 5   {'resource': 'TOTAL', 'total': 324, 'found': 3...      False
# 6   {'resource': 'TOTAL', 'total': 2, 'found': 1, ...      False
# 7   {'resource': 'TOTAL', 'total': 37, 'found': 1,...      False
# 8   {'resource': 'TOTAL', 'total': 2, 'found': 2, ...      False
# 9   {'resource': 'TOTAL', 'total': 4, 'found': 4, ...      False
# 10  {'resource': 'TOTAL', 'total': 4, 'found': 4, ...      False
# 11  {'resource': 'TOTAL', 'total': 7, 'found': 4, ...      False
# 12  {'resource': 'TOTAL', 'total': 4, 'found': 4, ...      False
# 13  {'resource': 'TOTAL', 'total': 5, 'found': 5, ...      False
# 14  {'resource': 'TOTAL', 'total': 4, 'found': 3, ...      False
# 15  {'resource': 'TOTAL', 'total': 2, 'found': 1, ...      False
# 16  {'resource': 'TOTAL', 'total': 6, 'found': 1, ...      False
# 17  {'resource': 'TOTAL', 'total': 7, 'found': 1, ...      False
# 18  {'resource': 'TOTAL', 'total': 556, 'found': 3...      False
# 19  {'resource': 'TOTAL', 'total': 5, 'found': 1, ...      False
# 20  {'resource': 'TOTAL', 'total': 14, 'found': 13...      False
# 21  {'resource': 'TOTAL', 'total': 7, 'found': 3, ...      False
# 22  {'resource': 'TOTAL', 'total': 14, 'found': 3,...      False
# 23  {'resource': 'TOTAL', 'total': 12, 'found': 1,...      False
# 24  {'resource': 'TOTAL', 'total': 13, 'found': 1,...      False
# 25  {'resource': 'TOTAL', 'total': 26, 'found': 2,...      False
# 26  {'resource': 'TOTAL', 'total': 21, 'found': 1,...      False
# 27  {'resource': 'TOTAL', 'total': 25, 'found': 1,...      False
# 28  {'resource': 'TOTAL', 'total': 28, 'found': 1,...      False
# 29  {'resource': 'TOTAL', 'total': 16, 'found': 2,...      False
# 30  {'resource': 'TOTAL', 'total': 28, 'found': 5,...      False
# 31  {'resource': 'TOTAL', 'total': 51, 'found': 21...      False
# 32  {'resource': 'TOTAL', 'total': 28, 'found': 3,...      False
# 33  {'resource': 'TOTAL', 'total': 27, 'found': 1,...      False
# 34  {'resource': 'TOTAL', 'total': 33, 'found': 21...      False
# 35  {'resource': 'TOTAL', 'total': 49, 'found': 1,...      False
# 36  {'resource': 'TOTAL', 'total': 34, 'found': 3,...      False
# 37  {'resource': 'TOTAL', 'total': 37, 'found': 1,...      False
# 38  {'resource': 'TOTAL', 'total': 206, 'found': 4...      False
# 39  {'resource': 'TOTAL', 'total': 77, 'found': 23...      False
# 40  {'resource': 'TOTAL', 'total': 30, 'found': 3,...      False
# 41  {'resource': 'TOTAL', 'total': 54, 'found': 1,...      False
# 42  {'resource': 'TOTAL', 'total': 60, 'found': 1,...      False
# 43  {'resource': 'TOTAL', 'total': 51, 'found': 1,...      False
# 44  {'resource': 'TOTAL', 'total': 92, 'found': 3,...      False
# 45  {'resource': 'TOTAL', 'total': 88, 'found': 21...      False
# 46  {'resource': 'TOTAL', 'total': 45, 'found': 2,...      False
# 47  {'resource': 'TOTAL', 'total': 144, 'found': 1...      False
# 48  {'resource': 'TOTAL', 'total': 319, 'found': 2...      False
# 49  {'resource': 'TOTAL', 'total': 157, 'found': 1...      False
# 50  {'resource': 'TOTAL', 'total': 243, 'found': 2...      False
# 51  {'resource': 'TOTAL', 'total': 744, 'found': 1...      False
# 52  {'resource': 'TOTAL', 'total': 107, 'found': 3...      False
# 53  {'resource': 'TOTAL', 'total': 334, 'found': 3...      False
# 54  {'resource': 'TOTAL', 'total': 442, 'found': 2...      False
# 55  {'resource': 'TOTAL', 'total': 264, 'found': 1...      False
# 56  {'resource': 'TOTAL', 'total': 1000, 'found': ...      False
# 57  {'resource': 'TOTAL', 'total': 2445, 'found': ...      False
# 58  {'resource': 'TOTAL', 'total': 1623, 'found': ...      False
# 59  {'resource': 'TOTAL', 'total': 2250, 'found': ...      False

# %%
import scanpy as sc
sc.settings.set_figure_params(dpi=300, facecolor='white')

# %%
sc.pl.umap(loaded_adata, color="Main_cluster_name")

# %%
from descartes_rpa.pl import shared_pathways

# %%
shared_pathways(adata)
