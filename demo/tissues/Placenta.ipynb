# %%
from descartes_rpa.convert.loom import loom_to_anndata
from descartes_rpa.analyze.analyze import scanpy_format
from descartes_rpa import get_pathways_for_group
from descartes_rpa.fetch.descartes import fetch_descartes_by_tissue

# %%
fetch_descartes_by_tissue(["Placenta"], out_dir="../data/input")
# Out:
# Downloading Placenta tissue Human Single-Cell data from Descartes database
# data url: https://shendure-web.gs.washington.edu/content/members/cao1025/public/FCA_RNA_supp_files/scanpy_cells_by_tissue/Placenta_processed.loom
# Downloaded ../data/input/Placenta_data.loom to ../data/input

# %%
adata = loom_to_anndata("../data/input/Placenta_data.loom")
scanpy_format(adata=adata)
get_pathways_for_group(adata)
# Out:
# /home/joao/miniconda3/envs/descartes-rpa/lib/python3.9/site-packages/anndata/_core/anndata.py:120: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/joao/miniconda3/envs/descartes-rpa/lib/python3.9/site-packages/anndata/utils.py:111: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-5', 'SNORD116-6']
#   warnings.warn(
# ... storing 'Assay' as categorical
# ... storing 'Experiment_batch' as categorical
# ... storing 'Fetus_id' as categorical
# ... storing 'Main_cluster_name' as categorical
# ... storing 'Organ' as categorical
# ... storing 'Organ_cell_lineage' as categorical
# ... storing 'RT_group' as categorical
# ... storing 'Sex' as categorical
# ... storing 'exon_intron' as categorical
# ... storing 'gene_type' as categorical

# %%
from descartes_rpa.io.save import save_data_with_pathways

# %%
import os
dir_path = "../data/output/Placenta"
os.mkdir(dir_path)
file = "Placenta"

# %%
save_data_with_pathways(adata, directory=dir_path, file=file)
# Out:
# Saving AnnData structure to ../data/output/Placenta/Placenta.h5ad
# Saving pathway data from Stromal cells clusters to ../data/output/Placenta
# Saving pathway data from Syncytiotrophoblasts and villous cytotrophoblasts clusters to ../data/output/Placenta
# Saving pathway data from IGFBP1_DKK1 positive cells clusters to ../data/output/Placenta
# Saving pathway data from Extravillous trophoblasts clusters to ../data/output/Placenta
# Saving pathway data from AFP_ALB positive cells clusters to ../data/output/Placenta
# Saving pathway data from Trophoblast giant cells clusters to ../data/output/Placenta
# Saving pathway data from Vascular endothelial cells clusters to ../data/output/Placenta
# Saving pathway data from PAEP_MECOM positive cells clusters to ../data/output/Placenta
# Saving pathway data from Lymphoid cells clusters to ../data/output/Placenta
# Saving pathway data from Myeloid cells clusters to ../data/output/Placenta
# Saving pathway data from Smooth muscle cells clusters to ../data/output/Placenta
# Saving pathway data from Megakaryocytes clusters to ../data/output/Placenta

# %%
from descartes_rpa.io.load import load_data_with_pathways

# %%
loaded_adata = load_data_with_pathways(directory=dir_path)
# Out:
# Loading ../data/output/Placenta/Smooth_muscle_cells_pathways.csv pathway data.
# Loading ../data/output/Placenta/Myeloid_cells_pathways.csv pathway data.
# Loading ../data/output/Placenta/Trophoblast_giant_cells_pathways.csv pathway data.
# Loading ../data/output/Placenta/Syncytiotrophoblasts_and_villous_cytotrophoblasts_pathways.csv pathway data.
# Loading ../data/output/Placenta/Megakaryocytes_pathways.csv pathway data.
# Loading ../data/output/Placenta/Lymphoid_cells_pathways.csv pathway data.
# Loading ../data/output/Placenta/Vascular_endothelial_cells_pathways.csv pathway data.
# Loading ../data/output/Placenta/Extravillous_trophoblasts_pathways.csv pathway data.
# Loading ../data/output/Placenta/AFP_ALB_positive_cells_pathways.csv pathway data.
# Loading ../data/output/Placenta/Stromal_cells_pathways.csv pathway data.
# Loading ../data/output/Placenta/IGFBP1_DKK1_positive_cells_pathways.csv pathway data.
# Loading ../data/output/Placenta/PAEP_MECOM_positive_cells_pathways.csv pathway data.
# Loading ../data/output/Placenta/Placenta.h5ad AnnData file.

# %%
loaded_adata.uns["pathways"].keys()
# Out:
# odict_keys(['Smooth_muscle_cells', 'Myeloid_cells', 'Trophoblast_giant_cells', 'Syncytiotrophoblasts_and_villous_cytotrophoblasts', 'Megakaryocytes', 'Lymphoid_cells', 'Vascular_endothelial_cells', 'Extravillous_trophoblasts', 'AFP_ALB_positive_cells', 'Stromal_cells', 'IGFBP1_DKK1_positive_cells', 'PAEP_MECOM_positive_cells'])

# %%
loaded_adata.uns["pathways"]["Vascular_endothelial_cells"]
# Out:
#               stId     dbId  \
# 0     R-HSA-428359   428359
# 1    R-HSA-2214320  2214320
# 2     R-HSA-216083   216083
# 3    R-HSA-2243919  2243919
# 4    R-HSA-3000157  3000157
# ..             ...      ...
# 99   R-HSA-8953897  8953897
# 100    R-HSA-73857    73857
# 101    R-HSA-74160    74160
# 102   R-HSA-597592   597592
# 103  R-HSA-1430728  1430728
#
#                                                   name  \
# 0    Insulin-like Growth Factor-2 mRNA Binding Prot...
# 1                           Anchoring fibril formation
# 2                   Integrin cell surface interactions
# 3                     Crosslinking of collagen fibrils
# 4                                 Laminin interactions
# ..                                                 ...
# 99                       Cellular responses to stimuli
# 100                    RNA Polymerase II Transcription
# 101                    Gene expression (Transcription)
# 102            Post-translational protein modification
# 103                                         Metabolism
#
#                                                species    llp  \
# 0    {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...   True
# 1    {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...   True
# 2    {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...   True
# 3    {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...   True
# 4    {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...   True
# ..                                                 ...    ...
# 99   {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...  False
# 100  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...  False
# 101  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...  False
# 102  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...  False
# 103  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...  False
#
#                                               entities  \
# 0    {'resource': 'TOTAL', 'total': 13, 'found': 3,...
# 1    {'resource': 'TOTAL', 'total': 15, 'found': 2,...
# 2    {'resource': 'TOTAL', 'total': 86, 'found': 3,...
# 3    {'resource': 'TOTAL', 'total': 24, 'found': 2,...
# 4    {'resource': 'TOTAL', 'total': 31, 'found': 2,...
# ..                                                 ...
# 99   {'resource': 'TOTAL', 'total': 966, 'found': 1...
# 100  {'resource': 'TOTAL', 'total': 1694, 'found': ...
# 101  {'resource': 'TOTAL', 'total': 1855, 'found': ...
# 102  {'resource': 'TOTAL', 'total': 1598, 'found': ...
# 103  {'resource': 'TOTAL', 'total': 3633, 'found': ...
#
#                                              reactions  inDisease
# 0    {'resource': 'TOTAL', 'total': 3, 'found': 3, ...      False
# 1    {'resource': 'TOTAL', 'total': 4, 'found': 1, ...      False
# 2    {'resource': 'TOTAL', 'total': 55, 'found': 8,...      False
# 3    {'resource': 'TOTAL', 'total': 13, 'found': 1,...      False
# 4    {'resource': 'TOTAL', 'total': 15, 'found': 3,...      False
# ..                                                 ...        ...
# 99   {'resource': 'TOTAL', 'total': 412, 'found': 1...      False
# 100  {'resource': 'TOTAL', 'total': 885, 'found': 8...      False
# 101  {'resource': 'TOTAL', 'total': 1000, 'found': ...      False
# 102  {'resource': 'TOTAL', 'total': 526, 'found': 2...      False
# 103  {'resource': 'TOTAL', 'total': 2250, 'found': ...      False
#
# [104 rows x 8 columns]

# %%
import scanpy as sc
sc.settings.set_figure_params(dpi=300, facecolor='white')

# %%
sc.pl.umap(loaded_adata, color="Main_cluster_name")
