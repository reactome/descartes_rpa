# %%
from descartes_rpa.convert.loom import loom_to_anndata
from descartes_rpa.analyze.analyze import scanpy_format
from descartes_rpa import get_pathways_for_group
from descartes_rpa.fetch.descartes import fetch_descartes_by_tissue

# %%
fetch_descartes_by_tissue(["Spleen"], out_dir="../data/input")
# Out:
# Downloading Spleen tissue Human Single-Cell data from Descartes database
# data url: https://shendure-web.gs.washington.edu/content/members/cao1025/public/FCA_RNA_supp_files/scanpy_cells_by_tissue/Spleen_processed.loom
# Downloaded ../data/input/Spleen_data.loom to ../data/input

# %%
adata = loom_to_anndata("../data/input/Spleen_data.loom")
scanpy_format(adata=adata)
get_pathways_for_group(adata)
# Out:
# /home/joao/miniconda3/envs/descartes-rpa/lib/python3.9/site-packages/anndata/_core/anndata.py:120: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/joao/miniconda3/envs/descartes-rpa/lib/python3.9/site-packages/anndata/utils.py:111: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-5', 'SNORD116-6']
#   warnings.warn(
# ... storing 'Assay' as categorical
# ... storing 'Experiment_batch' as categorical
# ... storing 'Fetus_id' as categorical
# ... storing 'Main_cluster_name' as categorical
# ... storing 'Organ' as categorical
# ... storing 'Organ_cell_lineage' as categorical
# ... storing 'RT_group' as categorical
# ... storing 'Sex' as categorical
# ... storing 'exon_intron' as categorical
# ... storing 'gene_type' as categorical

# %%
from descartes_rpa.io.save import save_data_with_pathways

# %%
import os
dir_path = "../data/output/Spleen"
os.mkdir(dir_path)
file = "Spleen"

# %%
save_data_with_pathways(adata, directory=dir_path, file=file)
# Out:
# Saving AnnData structure to ../data/output/Spleen/Spleen.h5ad
# Saving pathway data from Vascular endothelial cells clusters to ../data/output/Spleen
# Saving pathway data from Stromal cells clusters to ../data/output/Spleen
# Saving pathway data from STC2_TLX1 positive cells clusters to ../data/output/Spleen
# Saving pathway data from Myeloid cells clusters to ../data/output/Spleen
# Saving pathway data from Erythroblasts clusters to ../data/output/Spleen
# Saving pathway data from Lymphoid cells clusters to ../data/output/Spleen
# Saving pathway data from AFP_ALB positive cells clusters to ../data/output/Spleen
# Saving pathway data from Mesothelial cells clusters to ../data/output/Spleen
# Saving pathway data from Megakaryocytes clusters to ../data/output/Spleen

# %%
from descartes_rpa.io.load import load_data_with_pathways

# %%
loaded_adata = load_data_with_pathways(directory=dir_path)
# Out:
# Loading ../data/output/Spleen/Myeloid_cells_pathways.csv pathway data.
# Loading ../data/output/Spleen/Megakaryocytes_pathways.csv pathway data.
# Loading ../data/output/Spleen/Lymphoid_cells_pathways.csv pathway data.
# Loading ../data/output/Spleen/Vascular_endothelial_cells_pathways.csv pathway data.
# Loading ../data/output/Spleen/STC2_TLX1_positive_cells_pathways.csv pathway data.
# Loading ../data/output/Spleen/Mesothelial_cells_pathways.csv pathway data.
# Loading ../data/output/Spleen/Erythroblasts_pathways.csv pathway data.
# Loading ../data/output/Spleen/AFP_ALB_positive_cells_pathways.csv pathway data.
# Loading ../data/output/Spleen/Stromal_cells_pathways.csv pathway data.
# Loading ../data/output/Spleen/Spleen.h5ad AnnData file.

# %%
loaded_adata.uns["pathways"].keys()
# Out:
# odict_keys(['Myeloid_cells', 'Megakaryocytes', 'Lymphoid_cells', 'Vascular_endothelial_cells', 'STC2_TLX1_positive_cells', 'Mesothelial_cells', 'Erythroblasts', 'AFP_ALB_positive_cells', 'Stromal_cells'])

# %%
loaded_adata.uns["pathways"]["Myeloid_cells"]
# Out:
#               stId     dbId  \
# 0    R-HSA-5218921  5218921
# 1     R-HSA-114516   114516
# 2    R-HSA-8939246  8939246
# 3    R-HSA-3858494  3858494
# 4     R-HSA-416993   416993
# ..             ...      ...
# 163  R-HSA-1430728  1430728
# 164  R-HSA-8953854  8953854
# 165  R-HSA-1266738  1266738
# 166   R-HSA-392499   392499
# 167   R-HSA-597592   597592
#
#                                                   name  \
# 0                   VEGFR2 mediated cell proliferation
# 1                     Disinhibition of SNARE formation
# 2    RUNX1 regulates transcription of genes involve...
# 3               Beta-catenin independent WNT signaling
# 4       Trafficking of GluR2-containing AMPA receptors
# ..                                                 ...
# 163                                         Metabolism
# 164                                  Metabolism of RNA
# 165                              Developmental Biology
# 166                             Metabolism of proteins
# 167            Post-translational protein modification
#
#                                                species    llp  \
# 0    {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...   True
# 1    {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...   True
# 2    {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...   True
# 3    {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...  False
# 4    {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...   True
# ..                                                 ...    ...
# 163  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...  False
# 164  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...  False
# 165  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...  False
# 166  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...  False
# 167  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...  False
#
#                                               entities  \
# 0    {'resource': 'TOTAL', 'total': 31, 'found': 3,...
# 1    {'resource': 'TOTAL', 'total': 10, 'found': 2,...
# 2    {'resource': 'TOTAL', 'total': 11, 'found': 2,...
# 3    {'resource': 'TOTAL', 'total': 166, 'found': 4...
# 4    {'resource': 'TOTAL', 'total': 23, 'found': 2,...
# ..                                                 ...
# 163  {'resource': 'TOTAL', 'total': 3633, 'found': ...
# 164  {'resource': 'TOTAL', 'total': 782, 'found': 1...
# 165  {'resource': 'TOTAL', 'total': 1262, 'found': ...
# 166  {'resource': 'TOTAL', 'total': 2205, 'found': ...
# 167  {'resource': 'TOTAL', 'total': 1598, 'found': ...
#
#                                              reactions  inDisease
# 0    {'resource': 'TOTAL', 'total': 12, 'found': 6,...      False
# 1    {'resource': 'TOTAL', 'total': 2, 'found': 2, ...      False
# 2    {'resource': 'TOTAL', 'total': 7, 'found': 2, ...      False
# 3    {'resource': 'TOTAL', 'total': 51, 'found': 7,...      False
# 4    {'resource': 'TOTAL', 'total': 3, 'found': 2, ...      False
# ..                                                 ...        ...
# 163  {'resource': 'TOTAL', 'total': 2250, 'found': ...      False
# 164  {'resource': 'TOTAL', 'total': 187, 'found': 1...      False
# 165  {'resource': 'TOTAL', 'total': 556, 'found': 4...      False
# 166  {'resource': 'TOTAL', 'total': 798, 'found': 6...      False
# 167  {'resource': 'TOTAL', 'total': 526, 'found': 5...      False
#
# [168 rows x 8 columns]

# %%
import scanpy as sc
sc.settings.set_figure_params(dpi=300, facecolor='white')

# %%
sc.pl.umap(loaded_adata, color="Main_cluster_name")
