# %%
from descartes_rpa.convert.loom import loom_to_anndata
from descartes_rpa.analyze.analyze import scanpy_format
from descartes_rpa import get_pathways_for_group
from descartes_rpa.fetch.descartes import fetch_descartes_by_tissue

# %%
fetch_descartes_by_tissue(["Eye"], out_dir="../data/input")
# Out:
# Downloading Eye tissue Human Single-Cell data from Descartes database
# data url: https://shendure-web.gs.washington.edu/content/members/cao1025/public/FCA_RNA_supp_files/scanpy_cells_by_tissue/Eye_processed.loom
# Downloaded ../data/input/Eye_data.loom to ../data/input

# %%
adata = loom_to_anndata("../data/input/Eye_data.loom")
scanpy_format(adata=adata)
get_pathways_for_group(adata)
# Out:
# /home/joao/miniconda3/envs/descartes-rpa/lib/python3.9/site-packages/anndata/_core/anndata.py:120: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/joao/miniconda3/envs/descartes-rpa/lib/python3.9/site-packages/anndata/utils.py:111: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-5', 'SNORD116-6']
#   warnings.warn(
# ... storing 'Assay' as categorical
# ... storing 'Experiment_batch' as categorical
# ... storing 'Fetus_id' as categorical
# ... storing 'Main_cluster_name' as categorical
# ... storing 'Organ' as categorical
# ... storing 'Organ_cell_lineage' as categorical
# ... storing 'RT_group' as categorical
# ... storing 'Sex' as categorical
# ... storing 'exon_intron' as categorical
# ... storing 'gene_type' as categorical

# %%
from descartes_rpa.io.save import save_data_with_pathways
import os

# %%
dir_path = "../data/output/Eye"
os.mkdir(dir_path)
file = "Eye"

# %%
save_data_with_pathways(adata, directory=dir_path, file=file)
# Out:
# Saving AnnData structure to ../data/output/Eye/Eye.h5ad
# Saving pathway data from Retinal progenitors and Muller glia clusters to ../data/output/Eye
# Saving pathway data from Amacrine cells clusters to ../data/output/Eye
# Saving pathway data from Photoreceptor cells clusters to ../data/output/Eye
# Saving pathway data from Bipolar cells clusters to ../data/output/Eye
# Saving pathway data from Ganglion cells clusters to ../data/output/Eye
# Saving pathway data from Retinal pigment cells clusters to ../data/output/Eye
# Saving pathway data from Horizontal cells clusters to ../data/output/Eye
# Saving pathway data from Lens fibre cells clusters to ../data/output/Eye
# Saving pathway data from Vascular endothelial cells clusters to ../data/output/Eye
# Saving pathway data from Stromal cells clusters to ../data/output/Eye
# Saving pathway data from Corneal and conjunctival epithelial cells clusters to ../data/output/Eye
# Saving pathway data from PDE11A_FAM19A2 positive cells clusters to ../data/output/Eye
# Saving pathway data from Astrocytes clusters to ../data/output/Eye
# Saving pathway data from Microglia clusters to ../data/output/Eye
# Saving pathway data from Smooth muscle cells clusters to ../data/output/Eye
# Saving pathway data from Skeletal muscle cells clusters to ../data/output/Eye

# %%
from descartes_rpa.io.load import load_data_with_pathways

# %%
loaded_adata = load_data_with_pathways(directory=dir_path)
# Out:
# Loading ../data/output/Eye/Smooth_muscle_cells_pathways.csv pathway data.
# Loading ../data/output/Eye/Amacrine_cells_pathways.csv pathway data.
# Loading ../data/output/Eye/Lens_fibre_cells_pathways.csv pathway data.
# Loading ../data/output/Eye/Bipolar_cells_pathways.csv pathway data.
# Loading ../data/output/Eye/Retinal_pigment_cells_pathways.csv pathway data.
# Loading ../data/output/Eye/Horizontal_cells_pathways.csv pathway data.
# Loading ../data/output/Eye/Photoreceptor_cells_pathways.csv pathway data.
# Loading ../data/output/Eye/Ganglion_cells_pathways.csv pathway data.
# Loading ../data/output/Eye/Astrocytes_pathways.csv pathway data.
# Loading ../data/output/Eye/Vascular_endothelial_cells_pathways.csv pathway data.
# Loading ../data/output/Eye/Retinal_progenitors_and_Muller_glia_pathways.csv pathway data.
# Loading ../data/output/Eye/Microglia_pathways.csv pathway data.
# Loading ../data/output/Eye/Corneal_and_conjunctival_epithelial_cells_pathways.csv pathway data.
# Loading ../data/output/Eye/PDE11A_FAM19A2_positive_cells_pathways.csv pathway data.
# Loading ../data/output/Eye/Stromal_cells_pathways.csv pathway data.
# Loading ../data/output/Eye/Skeletal_muscle_cells_pathways.csv pathway data.
# Loading ../data/output/Eye/Eye.h5ad AnnData file.

# %%
loaded_adata.uns["pathways"].keys()
# Out:
# odict_keys(['Smooth_muscle_cells', 'Amacrine_cells', 'Lens_fibre_cells', 'Bipolar_cells', 'Retinal_pigment_cells', 'Horizontal_cells', 'Photoreceptor_cells', 'Ganglion_cells', 'Astrocytes', 'Vascular_endothelial_cells', 'Retinal_progenitors_and_Muller_glia', 'Microglia', 'Corneal_and_conjunctival_epithelial_cells', 'PDE11A_FAM19A2_positive_cells', 'Stromal_cells', 'Skeletal_muscle_cells'])

# %%
loaded_adata.uns["pathways"]["Photoreceptor_cells"]
# Out:
#               stId     dbId                                     name  \
# 0    R-HSA-1306955  1306955           GRB7 events in ERBB2 signaling
# 1    R-HSA-8847993  8847993           ERBB2 Activates PTK6 Signaling
# 2    R-HSA-6785631  6785631            ERBB2 Regulates Cell Motility
# 3    R-HSA-1963642  1963642           PI3K events in ERBB2 signaling
# 4    R-HSA-1358803  1358803  Downregulation of ERBB2:ERBB3 signaling
# ..             ...      ...                                      ...
# 118    R-HSA-73857    73857          RNA Polymerase II Transcription
# 119    R-HSA-74160    74160          Gene expression (Transcription)
# 120   R-HSA-556833   556833                     Metabolism of lipids
# 121   R-HSA-168256   168256                            Immune System
# 122  R-HSA-1430728  1430728                               Metabolism
#
#                                                species    llp  \
# 0    {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...   True
# 1    {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...   True
# 2    {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...   True
# 3    {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...   True
# 4    {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...   True
# ..                                                 ...    ...
# 118  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...  False
# 119  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...  False
# 120  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...  False
# 121  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...  False
# 122  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...  False
#
#                                               entities  \
# 0    {'resource': 'TOTAL', 'total': 6, 'found': 2, ...
# 1    {'resource': 'TOTAL', 'total': 18, 'found': 2,...
# 2    {'resource': 'TOTAL', 'total': 19, 'found': 2,...
# 3    {'resource': 'TOTAL', 'total': 22, 'found': 2,...
# 4    {'resource': 'TOTAL', 'total': 16, 'found': 2,...
# ..                                                 ...
# 118  {'resource': 'TOTAL', 'total': 1694, 'found': ...
# 119  {'resource': 'TOTAL', 'total': 1855, 'found': ...
# 120  {'resource': 'TOTAL', 'total': 1437, 'found': ...
# 121  {'resource': 'TOTAL', 'total': 2681, 'found': ...
# 122  {'resource': 'TOTAL', 'total': 3633, 'found': ...
#
#                                              reactions  inDisease
# 0    {'resource': 'TOTAL', 'total': 1, 'found': 1, ...      False
# 1    {'resource': 'TOTAL', 'total': 2, 'found': 2, ...      False
# 2    {'resource': 'TOTAL', 'total': 2, 'found': 2, ...      False
# 3    {'resource': 'TOTAL', 'total': 7, 'found': 4, ...      False
# 4    {'resource': 'TOTAL', 'total': 8, 'found': 2, ...      False
# ..                                                 ...        ...
# 118  {'resource': 'TOTAL', 'total': 885, 'found': 8...      False
# 119  {'resource': 'TOTAL', 'total': 1000, 'found': ...      False
# 120  {'resource': 'TOTAL', 'total': 949, 'found': 1...      False
# 121  {'resource': 'TOTAL', 'total': 1623, 'found': ...      False
# 122  {'resource': 'TOTAL', 'total': 2250, 'found': ...      False
#
# [123 rows x 8 columns]

# %%
import scanpy as sc
sc.settings.set_figure_params(dpi=300, facecolor='white')

# %%
sc.pl.umap(loaded_adata, color="Main_cluster_name")
