# %%
from descartes_rpa.convert.loom import loom_to_anndata
from descartes_rpa.analyze.analyze import scanpy_format
from descartes_rpa.analyze.analyze import get_pathways_for_group
from descartes_rpa.fetch.descartes import fetch_descartes_by_tissue

# %%
fetch_descartes_by_tissue(["Muscle"], out_dir="../data/input")
# Out:
# Downloading Muscle tissue Human Single-Cell data from Descartes database
# data url: https://shendure-web.gs.washington.edu/content/members/cao1025/public/FCA_RNA_supp_files/scanpy_cells_by_tissue/Muscle_processed.loom
# Downloaded ../data/input/Muscle_data.loom to ../data/input

# %%
adata = loom_to_anndata("../data/input/Muscle_data.loom")
scanpy_format(adata=adata)
get_pathways_for_group(adata)
# Out:
# /home/joao/miniconda3/envs/descartes-rpa/lib/python3.9/site-packages/anndata/_core/anndata.py:120: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/joao/miniconda3/envs/descartes-rpa/lib/python3.9/site-packages/anndata/utils.py:111: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-5', 'SNORD116-6']
#   warnings.warn(
# ... storing 'Assay' as categorical
# ... storing 'Experiment_batch' as categorical
# ... storing 'Fetus_id' as categorical
# ... storing 'Main_cluster_name' as categorical
# ... storing 'Organ' as categorical
# ... storing 'Organ_cell_lineage' as categorical
# ... storing 'RT_group' as categorical
# ... storing 'Sex' as categorical
# ... storing 'exon_intron' as categorical
# ... storing 'gene_type' as categorical

# %%
from descartes_rpa.io.save import save_data_with_pathways

# %%
import os
dir_path = "../data/output/Muscle"
os.mkdir(dir_path)
file = "Muscle"

# %%
save_data_with_pathways(adata, directory=dir_path, file=file)
# Out:
# Saving AnnData structure to ../data/output/Muscle/Muscle.h5ad
# Saving pathway data from Satellite cells clusters to ../data/output/Muscle
# Saving pathway data from Skeletal muscle cells clusters to ../data/output/Muscle
# Saving pathway data from Stromal cells clusters to ../data/output/Muscle
# Saving pathway data from Vascular endothelial cells clusters to ../data/output/Muscle
# Saving pathway data from Schwann cells clusters to ../data/output/Muscle
# Saving pathway data from Lymphoid cells clusters to ../data/output/Muscle
# Saving pathway data from Smooth muscle cells clusters to ../data/output/Muscle
# Saving pathway data from Myeloid cells clusters to ../data/output/Muscle
# Saving pathway data from Erythroblasts clusters to ../data/output/Muscle
# Saving pathway data from Megakaryocytes clusters to ../data/output/Muscle
# Saving pathway data from Lymphatic endothelial cells clusters to ../data/output/Muscle

# %%
from descartes_rpa.io.load import load_data_with_pathways

# %%
loaded_adata = load_data_with_pathways(directory=dir_path)
# Out:
# Loading ../data/output/Muscle/Lymphatic_endothelial_cells_pathways.csv pathway data.
# Loading ../data/output/Muscle/Smooth_muscle_cells_pathways.csv pathway data.
# Loading ../data/output/Muscle/Myeloid_cells_pathways.csv pathway data.
# Loading ../data/output/Muscle/Satellite_cells_pathways.csv pathway data.
# Loading ../data/output/Muscle/Megakaryocytes_pathways.csv pathway data.
# Loading ../data/output/Muscle/Lymphoid_cells_pathways.csv pathway data.
# Loading ../data/output/Muscle/Vascular_endothelial_cells_pathways.csv pathway data.
# Loading ../data/output/Muscle/Schwann_cells_pathways.csv pathway data.
# Loading ../data/output/Muscle/Erythroblasts_pathways.csv pathway data.
# Loading ../data/output/Muscle/Stromal_cells_pathways.csv pathway data.
# Loading ../data/output/Muscle/Skeletal_muscle_cells_pathways.csv pathway data.
# Loading ../data/output/Muscle/Muscle.h5ad AnnData file.

# %%
loaded_adata.uns["pathways"].keys()
# Out:
# odict_keys(['Lymphatic_endothelial_cells', 'Smooth_muscle_cells', 'Myeloid_cells', 'Satellite_cells', 'Megakaryocytes', 'Lymphoid_cells', 'Vascular_endothelial_cells', 'Schwann_cells', 'Erythroblasts', 'Stromal_cells', 'Skeletal_muscle_cells'])

# %%
loaded_adata.uns["pathways"]["Skeletal_muscle_cells"]
# Out:
#               stId     dbId  \
# 0     R-HSA-390522   390522
# 1     R-HSA-397014   397014
# 2     R-HSA-975956   975956
# 3    R-HSA-1799339  1799339
# 4     R-HSA-927802   927802
# ..             ...      ...
# 130  R-HSA-1280215  1280215
# 131    R-HSA-74160    74160
# 132   R-HSA-168249   168249
# 133   R-HSA-597592   597592
# 134   R-HSA-168256   168256
#
#                                                   name  \
# 0                          Striated Muscle Contraction
# 1                                   Muscle contraction
# 2    Nonsense Mediated Decay (NMD) independent of t...
# 3    SRP-dependent cotranslational protein targetin...
# 4                        Nonsense-Mediated Decay (NMD)
# ..                                                 ...
# 130                Cytokine Signaling in Immune system
# 131                    Gene expression (Transcription)
# 132                               Innate Immune System
# 133            Post-translational protein modification
# 134                                      Immune System
#
#                                                species    llp  \
# 0    {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...   True
# 1    {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...  False
# 2    {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...   True
# 3    {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...   True
# 4    {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...  False
# ..                                                 ...    ...
# 130  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...  False
# 131  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...  False
# 132  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...  False
# 133  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...  False
# 134  {'dbId': 48887, 'taxId': '9606', 'name': 'Homo...  False
#
#                                               entities  \
# 0    {'resource': 'TOTAL', 'total': 40, 'found': 15...
# 1    {'resource': 'TOTAL', 'total': 213, 'found': 1...
# 2    {'resource': 'TOTAL', 'total': 101, 'found': 4...
# 3    {'resource': 'TOTAL', 'total': 119, 'found': 4...
# 4    {'resource': 'TOTAL', 'total': 124, 'found': 4...
# ..                                                 ...
# 130  {'resource': 'TOTAL', 'total': 1092, 'found': ...
# 131  {'resource': 'TOTAL', 'total': 1855, 'found': ...
# 132  {'resource': 'TOTAL', 'total': 1334, 'found': ...
# 133  {'resource': 'TOTAL', 'total': 1598, 'found': ...
# 134  {'resource': 'TOTAL', 'total': 2681, 'found': ...
#
#                                              reactions  inDisease
# 0    {'resource': 'TOTAL', 'total': 4, 'found': 4, ...      False
# 1    {'resource': 'TOTAL', 'total': 42, 'found': 10...      False
# 2    {'resource': 'TOTAL', 'total': 1, 'found': 1, ...      False
# 3    {'resource': 'TOTAL', 'total': 5, 'found': 5, ...      False
# 4    {'resource': 'TOTAL', 'total': 6, 'found': 5, ...      False
# ..                                                 ...        ...
# 130  {'resource': 'TOTAL', 'total': 708, 'found': 1...      False
# 131  {'resource': 'TOTAL', 'total': 1000, 'found': ...      False
# 132  {'resource': 'TOTAL', 'total': 710, 'found': 1...      False
# 133  {'resource': 'TOTAL', 'total': 526, 'found': 3...      False
# 134  {'resource': 'TOTAL', 'total': 1623, 'found': ...      False
#
# [135 rows x 8 columns]

# %%
import scanpy as sc
sc.settings.set_figure_params(dpi=300, facecolor='white')

# %%
sc.pl.umap(loaded_adata, color="Main_cluster_name")
