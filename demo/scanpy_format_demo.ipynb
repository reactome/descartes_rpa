# %%
import numpy as np
import pandas as pd
import scanpy as sc

sc.settings.verbosity = 3             # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.logging.print_header()
sc.settings.set_figure_params(dpi=80, facecolor='white')
# Out:
# scanpy==1.7.2 anndata==0.7.6 umap==0.5.1 numpy==1.20.3 scipy==1.6.3 pandas==1.2.4 scikit-learn==0.24.2 statsmodels==0.12.2 python-igraph==0.9.1

# %%
from descartes_rpa.convert.loom import loom_to_anndata
adata = loom_to_anndata("../../Thymus_processed.loom")
# Out:
# /home/joao/anaconda3/envs/descartes_rpa/lib/python3.9/site-packages/anndata/_core/anndata.py:120: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)

# %%
adata.var
# Out:
#       exon_intron            gene_id gene_short_name       gene_type   index  \
# 0            exon  ENSG00000223972.4         DDX11L1      pseudogene       1
# 1            exon  ENSG00000227232.4          WASH7P      pseudogene       3
# 2            exon  ENSG00000243485.2      MIR1302-11         lincRNA       5
# 3            exon  ENSG00000237613.2         FAM138A         lincRNA       7
# 4            exon  ENSG00000268020.2          OR4G4P      pseudogene       9
# ...           ...                ...             ...             ...     ...
# 63556        exon  ENSG00000240779.1      CU463998.1           miRNA  127113
# 63557        exon  ENSG00000244656.1      CU463998.3           miRNA  127115
# 63558        exon  ENSG00000263760.1      CU463998.4           miRNA  127117
# 63559        exon  ENSG00000222670.2      CU459211.1           miRNA  127119
# 63560        exon  ENSG00000251180.2      CU459201.1  protein_coding  127121
#
#                var_names
# 0      ENSG00000223972.4
# 1      ENSG00000227232.4
# 2      ENSG00000243485.2
# 3      ENSG00000237613.2
# 4      ENSG00000268020.2
# ...                  ...
# 63556  ENSG00000240779.1
# 63557  ENSG00000244656.1
# 63558  ENSG00000263760.1
# 63559  ENSG00000222670.2
# 63560  ENSG00000251180.2
#
# [63561 rows x 6 columns]

# %% [markdown]
# ## This function formats the AnnData from Descartes loom, turning the index in the gene_short_name, and also creating "adata.obsm['X_umap']", since this is the expected format for plotting

# %%
# Import function to format descartes into scanpy API data

from descartes_rpa.analyze.analyze import scanpy_format

# %%
adata.var
# Out:
#       exon_intron            gene_id gene_short_name       gene_type   index  \
# 0            exon  ENSG00000223972.4         DDX11L1      pseudogene       1
# 1            exon  ENSG00000227232.4          WASH7P      pseudogene       3
# 2            exon  ENSG00000243485.2      MIR1302-11         lincRNA       5
# 3            exon  ENSG00000237613.2         FAM138A         lincRNA       7
# 4            exon  ENSG00000268020.2          OR4G4P      pseudogene       9
# ...           ...                ...             ...             ...     ...
# 63556        exon  ENSG00000240779.1      CU463998.1           miRNA  127113
# 63557        exon  ENSG00000244656.1      CU463998.3           miRNA  127115
# 63558        exon  ENSG00000263760.1      CU463998.4           miRNA  127117
# 63559        exon  ENSG00000222670.2      CU459211.1           miRNA  127119
# 63560        exon  ENSG00000251180.2      CU459201.1  protein_coding  127121
#
#                var_names
# 0      ENSG00000223972.4
# 1      ENSG00000227232.4
# 2      ENSG00000243485.2
# 3      ENSG00000237613.2
# 4      ENSG00000268020.2
# ...                  ...
# 63556  ENSG00000240779.1
# 63557  ENSG00000244656.1
# 63558  ENSG00000263760.1
# 63559  ENSG00000222670.2
# 63560  ENSG00000251180.2
#
# [63561 rows x 6 columns]

# %%
scanpy_format(adata=adata)
# Out:
# /home/joao/anaconda3/envs/descartes_rpa/lib/python3.9/site-packages/anndata/utils.py:111: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-5', 'SNORD116-6']
#   warnings.warn(

# %%
adata.var
# Out:
#                 exon_intron            gene_id       gene_type   index  \
# gene_short_name
# DDX11L1                exon  ENSG00000223972.4      pseudogene       1
# WASH7P                 exon  ENSG00000227232.4      pseudogene       3
# MIR1302-11             exon  ENSG00000243485.2         lincRNA       5
# FAM138A                exon  ENSG00000237613.2         lincRNA       7
# OR4G4P                 exon  ENSG00000268020.2      pseudogene       9
# ...                     ...                ...             ...     ...
# CU463998.1             exon  ENSG00000240779.1           miRNA  127113
# CU463998.3             exon  ENSG00000244656.1           miRNA  127115
# CU463998.4             exon  ENSG00000263760.1           miRNA  127117
# CU459211.1             exon  ENSG00000222670.2           miRNA  127119
# CU459201.1             exon  ENSG00000251180.2  protein_coding  127121
#
#                          var_names
# gene_short_name
# DDX11L1          ENSG00000223972.4
# WASH7P           ENSG00000227232.4
# MIR1302-11       ENSG00000243485.2
# FAM138A          ENSG00000237613.2
# OR4G4P           ENSG00000268020.2
# ...                            ...
# CU463998.1       ENSG00000240779.1
# CU463998.3       ENSG00000244656.1
# CU463998.4       ENSG00000263760.1
# CU459211.1       ENSG00000222670.2
# CU459201.1       ENSG00000251180.2
#
# [63561 rows x 5 columns]

# %%
sc.pl.umap(adata, color=["COL1A1", "SLIT3", "LEF1"])
# Out:
# ... storing 'Assay' as categorical
# ... storing 'Experiment_batch' as categorical
# ... storing 'Fetus_id' as categorical
# ... storing 'Main_cluster_name' as categorical
# ... storing 'Organ' as categorical
# ... storing 'Organ_cell_lineage' as categorical
# ... storing 'RT_group' as categorical
# ... storing 'Sex' as categorical
# ... storing 'exon_intron' as categorical
# ... storing 'gene_type' as categorical

# %%
adata.obs
# Out:
#       All_reads   Assay  Batch  Development_day  Exon_reads Experiment_batch  \
# 0           688  Nuclei      7              115         128             exp4
# 1           559  Nuclei      7              115         173             exp4
# 2           312  Nuclei      7              115         222             exp4
# 3           423  Nuclei      7              115          60             exp4
# 4           341  Nuclei      7              115         140             exp4
# ...         ...     ...    ...              ...         ...              ...
# 8774        429  Nuclei      4              110         174             exp3
# 8775        342  Nuclei      4              110          97             exp3
# 8776        311  Nuclei      4              110         130             exp3
# 8777        389  Nuclei      4              110         104             exp3
# 8778        733  Nuclei      4              110         201             exp3
#
#      Fetus_id  Intron_reads         Main_cluster_name  Main_cluster_umap_1  \
# 0      H27423           467                Thymocytes             1.480319
# 1      H27423           316                Thymocytes             1.836766
# 2      H27423            39                Thymocytes             1.720090
# 3      H27423           271                Thymocytes             1.329029
# 4      H27423           165                Thymocytes             1.674138
# ...       ...           ...                       ...                  ...
# 8774   H27471           176                Thymocytes             1.884309
# 8775   H27471           199                Thymocytes             1.933699
# 8776   H27471           137  Antigen presenting cells             1.491640
# 8777   H27471           231                Thymocytes             1.471399
# 8778   H27471           420                Thymocytes             1.236487
#
#       Main_cluster_umap_2   Organ               Organ_cell_lineage  \
# 0                1.717246  Thymus                Thymus-Thymocytes
# 1                0.828598  Thymus                Thymus-Thymocytes
# 2                1.417247  Thymus                Thymus-Thymocytes
# 3                0.776162  Thymus                Thymus-Thymocytes
# 4                1.022330  Thymus                Thymus-Thymocytes
# ...                   ...     ...                              ...
# 8774             1.473001  Thymus                Thymus-Thymocytes
# 8775             0.883870  Thymus                Thymus-Thymocytes
# 8776             2.114090  Thymus  Thymus-Antigen presenting cells
# 8777             1.168557  Thymus                Thymus-Thymocytes
# 8778             1.379843  Thymus                Thymus-Thymocytes
#
#            RT_group Sex  Size_Factor  n_counts  \
# 0     Thymus_H27423   M          NaN     592.0
# 1     Thymus_H27423   M          NaN     487.0
# 2     Thymus_H27423   M          NaN     252.0
# 3     Thymus_H27423   M          NaN     330.0
# 4     Thymus_H27423   M          NaN     304.0
# ...             ...  ..          ...       ...
# 8774  Thymus_H27471   F          NaN     349.0
# 8775  Thymus_H27471   F          NaN     293.0
# 8776  Thymus_H27471   F          NaN     266.0
# 8777  Thymus_H27471   F          NaN     332.0
# 8778  Thymus_H27471   F          NaN     619.0
#
#                                     obs_names  \
# 0      exp4-human-101well.ATGCTTCCTAACCATTGGA
# 1     exp4-human-103well.TTCCATTACTTTATTCATTC
# 2      exp4-human-103well.GACCGTCATCATTCGACGG
# 3      exp4-human-104well.CCAGCCTTTTAACTGGTTA
# 4      exp4-human-104well.CAAGCAACTTGGTCAGCCA
# ...                                       ...
# 8774   exp3-human-403well.AGAGTACCTTAGATCTACT
# 8775  exp3-human-410well.ACAACCTATTCATCTCTGCA
# 8776  exp3-human-423well.TTCTCATTGTACTTAACCTT
# 8777  exp3-human-476well.TCCAAGTTATATCCATGACT
# 8778   exp3-human-478well.GGTCAGTTTACCGCCAACC
#
#                                        sample
# 0      exp4-human-101well.ATGCTTCCTAACCATTGGA
# 1     exp4-human-103well.TTCCATTACTTTATTCATTC
# 2      exp4-human-103well.GACCGTCATCATTCGACGG
# 3      exp4-human-104well.CCAGCCTTTTAACTGGTTA
# 4      exp4-human-104well.CAAGCAACTTGGTCAGCCA
# ...                                       ...
# 8774   exp3-human-403well.AGAGTACCTTAGATCTACT
# 8775  exp3-human-410well.ACAACCTATTCATCTCTGCA
# 8776  exp3-human-423well.TTCTCATTGTACTTAACCTT
# 8777  exp3-human-476well.TCCAAGTTATATCCATGACT
# 8778   exp3-human-478well.GGTCAGTTTACCGCCAACC
#
# [8779 rows x 19 columns]

# %%
sc.tl.rank_genes_groups(adata, groupby='Main_cluster_name', method='wilcoxon')
# Out:
# ranking genes
#     finished: added to `.uns['rank_genes_groups']`
#     'names', sorted np.recarray to be indexed by group ids
#     'scores', sorted np.recarray to be indexed by group ids
#     'logfoldchanges', sorted np.recarray to be indexed by group ids
#     'pvals', sorted np.recarray to be indexed by group ids
#     'pvals_adj', sorted np.recarray to be indexed by group ids (0:00:29)

# %%
sc.pl.rank_genes_groups_dotplot(adata, n_genes=4)
# Out:
# WARNING: dendrogram data not found (using key=dendrogram_Main_cluster_name). Running `sc.tl.dendrogram` with default parameters. For fine tuning it is recommended to run `sc.tl.dendrogram` independently.
# WARNING: You’re trying to run this on 63561 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
# computing PCA
#     with n_comps=50
#     finished (0:00:10)
# Storing dendrogram info using `.uns['dendrogram_Main_cluster_name']`

# %%
sc.pl.correlation_matrix(adata, groupby="Main_cluster_name", figsize=(5,3.5))

# %%
sc.pl.highest_expr_genes(adata, n_top=50, )
# Out:
# normalizing counts per cell
#     finished (0:00:00)
